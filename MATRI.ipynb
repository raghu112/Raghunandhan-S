# %%
import csv
import logging

filename="Matrimonial.csv"
print("                                       Welcome to Matrimonial System                       ")
class value:
    def insert():                         #INSERTION
        name=input("Person Name:")
        age=int(input("Age:"))
        gender=input("Gender:")
        address=input("Address:")
        work=input("Work:")
        likes=input("Likes:")
        dislikes=input("Dislikes:")
        contact_number=eval(input("Enter number:"))
    
        with open(filename,'a',newline='')as file:
            csv_writer=csv.writer(file)
            csv_writer.writerow([name,age,gender,address,work,likes,dislikes,contact_number])
            
    def modify():                       #MODIFICATION
        with open(filename,'r') as file:
            data=csv.reader(file)
            for i in list(data):
                print("Enter the modifying as number,then enter details")
                n=int(input())
                mod=input()
                while True:
                    if n==1:
                        i[0]=mod
                    elif n==2:
                        i[1]=mod
                    elif n==3:
                        i[1]=mod
                    elif n==4:
                        i[1]=mod
                    elif n==5:
                        i[1]=mod
                    elif n==6:
                        i[1]=mod
                    elif n==7:
                        i[1]=mod
                    elif n==8:
                        i[1]=mod
                    print(f'{i[0]}\t\t{i[1]}\t\t{i[2]}\t\t{i[3]}\t\t{i[4]}\t\t{i[5]}\t\t{i[6]}\t\t{i[7]}')
                    break
            
    def retrive():                      #RETRIEVAL
        with open(filename,"r") as file:
            print('name\tage\tgender\taddress\twork\tlikes\tdislikes\tcontact_number')
            val=csv.reader(file)
            for i in list(val):
                print(f'{i[0]}\t\t{i[1]}\t\t{i[2]}\t\t{i[3]}\t\t{i[4]}\t\t{i[5]}\t\t{i[6]}\t\t{i[7]}')
    def search():
        a=input("Enter the Searching name:")
        with open(filename,'r') as file:
            data=csv.reader(file)
            List=list(data)
            result=[i for i in List if a in i]
            if len(result)>0:
                for j in list(result):
                    print(j[0],'\t',j[1],'\t',j[2],'\t',j[3],'\t',j[4],'\t',j[5],'\t',j[6],'\t',j[7],)
                else:
                    print("No need of search")
    def  recommendation():                  #RECCOMMENDATION
        with open(filename,"r") as file:
            val=csv.reader(file)
            b=int(input("Enter age"))
            for i in list(val):
                if i[1]==b:
                    print(f'{i[0]}\t{i[1]}\t{i[2]}\t{i[3]}\t{i[4]}\t{i[5]}\t{i[6]}\t{i[7]}')
    def delete():                          #DELETION
        with open(filename,"r+") as file:
            val=csv.reader(file)
            c=list(val)
            del c
            for i in list(val):
                print(f'{i[0]}\t{i[1]}\t{i[2]}\t{i[3]}\t{i[4]}\t{i[5]}\t{i[6]}\t{i[7]}')
        
    def Menu():                           #SELECT THE DETAILS
        print("Menu")
        print("1.INSERTION")
        print("2.MODIFICATION")
        print("3.RETRIEVAL")
        print("4.SEARCHING")
        print("5.RECOMMENDATION")
        print("6.DELETION")
        my_option=None
        try:
            my_option=eval(input("Enter the choice:"))
        except:
            logging.warning("Enter the number") #IT RETURNS WARNING
        return my_option
        option=int(input())
        return option
    while True:
        option=Menu()
        if option==1:
            insert()
        elif option==2:
            modify()
        elif option==3:
            retrive()
        elif option==4:
            search()
        elif option==5:
            recommendation()
        elif option==6:
            delete()
        else:
            exit()
        
mrg=value #CREATION OF OBJECT
# Out:
#                                        Welcome to Matrimonial System
# Menu
# 1.INSERTION
# 2.MODIFICATION
# 3.RETRIEVAL
# 4.SEARCHING
# 5.RECOMMENDATION
# 6.DELETION
# Enter the choice:4
# Enter the Searching name:DINESH KUMAR
# DINESH KUMAR 	 27 	 MALE 	 47/7B/1E,MARIAMMAN TEMPLE,TEPPAKULAM,MADURAI 	 SOFTWARE ENGINEER 	 AS A SOFTWARE ENGINNER 	 HOUSE WIF 	 9047957292
# No need of search
# Menu
# 1.INSERTION
# 2.MODIFICATION
# 3.RETRIEVAL
# 4.SEARCHING
# 5.RECOMMENDATION
# 6.DELETION
